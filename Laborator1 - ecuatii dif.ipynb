# %%
12+4-5
# Out:
# 11

# %%
2^10
# Out:
# 1024

# %%
sin(pi/2)
# Out:
# 1

# %%
sin(1./10)
# Out:
# 0.0998334166468282

# %%
14+2*(5-3)
# Out:
# 18

# %%
x=SR.var('x')
eq1=x^4-(3/2)*x^3-x+(3/2)==0
solve(eq1, x)
# Out:
# [x == 1, x == (3/2), x == -1/2*I*sqrt(3) - 1/2, x == 1/2*I*sqrt(3) - 1/2]

# %%
y=SR.var('y')
eq2=sqrt(x^2+2*x)==3-x
solve(eq2,x)
# Out:
# [x == -sqrt(x^2 + 2*x) + 3]

# %%
eq2 = 8x-9==0
solve(eq2, x)
# Out:
#   File "<ipython-input-8-0e4637b9e74b>", line 1
#     eq2 = 8x-Integer(9)==Integer(0)
#            ^
# SyntaxError: invalid syntax

# %%
y=SR.var('y')
eq2 = 8x-9==0
solve(eq2,y)
# Out:
#   File "<ipython-input-9-39fa9f65e989>", line 2
#     eq2 = 8x-Integer(9)==Integer(0)
#            ^
# SyntaxError: invalid syntax

# %%
y=SR.var('y')
eq2 = 8y-9==0
solve(eq2,y)
# Out:
#   File "<ipython-input-10-da88af06fab4>", line 2
#     eq2 = 8y-Integer(9)==Integer(0)
#            ^
# SyntaxError: invalid syntax

# %%
z=SR.var('z')
eq2=sqrt(z^2+2*z)-3+x==0
solve(eq2,z)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/interfaces/maxima_lib.py in _create(self, value, name)
#     604             else:
# --> 605                 self.set(name, value)
#     606         except RuntimeError as error:
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/interfaces/maxima_lib.py in set(self, var, value)
#     513         cmd = '%s : %s$'%(var, value.rstrip(';'))
# --> 514         self.eval(cmd)
#     515
#
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/interfaces/maxima_lib.py in _eval_line(self, line, locals, reformat, **kwds)
#     459                 if statement:
# --> 460                     maxima_eval("#$%s$" % statement)
#     461         if not reformat:
#
# ...

# %%
z=SR.var('z')
eq2=sqrt(z^2+2*z)-3+z==0
solve(eq2,z)
# Out:
# [z == -sqrt(z^2 + 2*z) + 3]

# %%
x, y = var('x, y')
syst = [ 2*x + y ==3, x+3*y==-1]
solve(syst, x, y)
# Out:
# [[x == 2, y == -1]]

# %%
reset()
x, y = var('x, y')
syst1=[2*x+x*y+2*y==59, 3*x -2*x*y+3*y==-34]
solve(syst1, x, y)
# Out:
# [[x == 7, y == 5], [x == 5, y == 7]]

# %%
x, y = var('x, y')
solve([2*x+x*y+2*y==59,3*x -2*x*y+3*y==-34], x, y)
# Out:
# [[x == 7, y == 5], [x == 5, y == 7]]

# %%
x,y = var('x,y')
solve([2*x + x*y +2*y == 59, 3*x -2*x*y + 3*y == -34], x , y)
# Out:
# [[x == 7, y == 5], [x == 5, y == 7]]

# %%
x=SR.var('x')
limit(sin(x)/x,x=0)
# Out:
# 1

# %%
x=SR.var('x')
limit((x^3+3*(x^2)-5)/(2*(x^3)-7*x), x=infinity)
# Out:
# 1/2

# %%
x=SR.var('x')
limit((cos(x)+1)/(x-pi), x=pi)
# Out:
# 0

# %%
x=SR.var('x')
y(x)=3*(x^3)+2*(x^2)-5
diff(y(x), x)
# Out:
# 9*x^2 + 4*x

# %%
x=SR.var('x')
y(x)=sqrt(1+(x^4))
diff(y(x), x)
# Out:
# 2*x^3/sqrt(x^4 + 1)

# %%
x=SR.var('x')
y(x)=exp(x)*sin(x)*cos(x)
diff(y(x), x)
# Out:
# cos(x)^2*e^x + cos(x)*e^x*sin(x) - e^x*sin(x)^2

# %%
x=SR.var('x')
integrate((3*(x^3)+2*(x^2)-5),x, 0, 1)
# Out:
# -43/12

# %%
x=SR.var('x')
integrate((1/(x^2)),x, 1, infinity)
# Out:
# 1

# %%
x=SR.var('x')
integrate(exp(-(x^2)),x, -infinity, infinity)
# Out:
# sqrt(pi)

# %%
x=SR.var('x')
f(x)=exp(-x)-1
plot(f(x), -2, 2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x, r=SR.var('x, r')
f(x)=(200*exp(r*x))/(2*(exp(r*x)-1)+100)

plot(f(x), 0, 50, r==0.5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /opt/sagemath-9.1/local/lib/python3.7/site-packages/sage/ext/fast_callable.pyx in sage.ext.fast_callable.ExpressionTreeBuilder.var (build/cythonized/sage/ext/fast_callable.c:6758)()
#     725         try:
# --> 726             ind = self._vars.index(var_name)
#     727         except ValueError:
#
# ValueError: 'x' is not in list
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-c8bee187c0ef> in <module>()
#       2 __tmp__=var("x"); f = symbolic_expression((Integer(200)*exp(r*x))/(Integer(2)*(exp(r*x)-Integer(1))+Integer(100))).function(x)
#       3
# ----> 4 plot(f(x), Integer(0), Integer(50), r==RealNumber('0.5'))
#
# ...

# %%
x=SR.var('x')
f(x)=(x*sin(1/x))
plot(f(x),-3,3)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
t=SR.var('t')
plot([(1-cos(t))*cos(t), (1-cos(t))*sin(t)],0,2*pi,color=['red','blue'])
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
t=SR.var('t')
plot([sin(3*t)*cos(t), sin(3*t)*sin(t)],0,2*pi,color=['red','blue'])
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
t=SR.var('t')
plot([t-sin(t), 1-cos(t)],0,6*pi,color=['red','blue'])
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
t=SR.var('t')
plot([cos(t)+(cos(7*t))/2+(sin(17*t))/3, sin(t)+(sin(7*t))/2+(cos(17*t))/3],0,2*pi,color=['red','blue'])
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
t,s=var('t,s')
f(t,s)=1-(s*cos(4*t)*cos(t))/sqrt(1-s^2*(cos(4*t)^2)*sin(t)^2)
parametric_plot((f(t-(pi/2), 0.5), f(t, 5./10)), (t,0, 2*pi))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
t,s=var('t,s')
f(t,s)= 1-(s*cos(4*t)*cos(t))/sqrt(1-s^2*cos(4*t)^2*sin(t)^2)
x(t)= f(t-(pi/2),0.5)
y(t)=f(t,0.5)
parametric_plot((x(t), y(t)), (t, 0, 2*pi))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x,y=var('x,y')
f(x,y)=x^2+y^2-2*x-4*y+4
implicit_plot(f(x,y)==0, (x,-10,10), (y,-10,10))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x,y=var('x,y')
f(x,y)=x^2+2*x*y-y^2
implicit_plot(f(x,y)==1, (x,-10,10), (y,-10,10))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x,y=var('x,y')
f(x,y)=6*(x^2)-4*x*y+9*(y^2)-4*x-32*y-6
implicit_plot(f(x,y)==0, (x,-10,10), (y,-10,10))
# Out:
# Graphics object consisting of 1 graphics primitive
